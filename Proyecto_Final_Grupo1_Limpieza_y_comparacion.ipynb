# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaloMejia/open_tests/blob/main/Proyecto_Final_Grupo1_Limpieza_y_comparacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Conectar con Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Accediendo a los datos

# %%
import pandas as pd
data_2022_2 = pd.read_excel('/content/drive/MyDrive/####Courses/###UTEC/Python (UTEC)/(UTEC) Proyecto Grupo 1 /Data 2022-2.xls')
data_2022_1 = pd.read_excel('/content/drive/MyDrive/####Courses/###UTEC/Python (UTEC)/(UTEC) Proyecto Grupo 1 /Data 2022-1.xls')

# %%
data_2022_2.head(30)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN        NaN        NaN
# 1          NaN         NaN         NaN         NaN        NaN        NaN
# 2          NaN         NaN         NaN         NaN        NaN        NaN
# 3          NaN         NaN         NaN         NaN        NaN        NaN
# 4          NaN         NaN         NaN         NaN        NaN        NaN
# 5          NaN         NaN         NaN         NaN        NaN        NaN
# 6          NaN         NaN         NaN  Práctica C        NaN        NaN
# 7          NaN         NaN         NaN           1          2          3
# 8          NaN         NaN         NaN           6         12          8
# 9          NaN         NaN         NaN           F          F          F
# 10         NaN         NaN         NaN          11         17         14
# 11         NaN         NaN         NaN          16         20         17
# 12         NaN         NaN         NaN          17         14         11
# 13         NaN         NaN         NaN          10         13         10
# 14         NaN         NaN         NaN           7         14         11
# 15         NaN         NaN         NaN          18         19         10
# 16         NaN         NaN         NaN           9          8         11
# 17         NaN         NaN         NaN          18         18         17
# 18         NaN         NaN         NaN          17         18         10
# 19         NaN         NaN         NaN          20         16         10
# 20         NaN         NaN         NaN          10          9          4
# 21         NaN         NaN         NaN           4         12          6
# 22         NaN         NaN         NaN          15         10          8
# 23         NaN         NaN         NaN          18         14          8
# 24         NaN         NaN         NaN          11          3          7
# 25         NaN         NaN         NaN           9         14          4
# 26         NaN         NaN         NaN          12         13          8
# 27         NaN         NaN         NaN           9          9          4
# 28         NaN         NaN         NaN           8          7          8
# 29         NaN         NaN         NaN           7         12          2
#
#    Unnamed: 6       Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0         NaN              NaN        NaN        NaN         NaN         NaN
# 1         NaN              NaN        NaN        NaN         NaN         NaN
# 2         NaN              NaN        NaN        NaN         NaN         NaN
# 3         NaN              NaN        NaN        NaN         NaN         NaN
# 4         NaN              NaN        NaN        NaN         NaN         NaN
# 5         NaN              NaN        NaN        NaN         NaN         NaN
# 6         NaN  Práctica tipo D        NaN        NaN         NaN      Examen
# 7           4                1          2          3           4           1
# 8           6               10         12         15          13          13
# 9           F                5          F          F           F           F
# 10         12               13         17         18          17          16
# 11         20               20         19         19          18          20
# 12         10               16         15         15          15          10
# 13         12               13         10         17          12          10
# 14         13                5         12         15          11          12
# 15         12               19         19         18          13          16
# 16         14               13         11         16          17          13
# 17         11               14         13         19          18          16
# 18         15               18         18         18          19          14
# 19         13               17         13         18          19          16
# 20         13               16         12         15          11          13
# 21          6               14         12         10          10           7
# 22         14               15         10          9          16           4
# 23         18               17         15         10          15          17
# 24          8               13         14         15           5           7
# 25         13               12         12          9          13          10
# 26         13               11         14         17          14          15
# 27          7               12         13         14           8           8
# 28          8               11         12          F           F           6
# 29          2               11         13         14          10          10
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN          E3        Nota
# 7            2           1         NaN
# 8            F          11          11
# 9            F           F    Retirado
# 10          15           F          15
# 11          19           F          19
# 12          12           F          12
# 13           9           F          11
# 14          10           F          12
# 15          13           F          16
# 16          13           F          13
# 17          12           F          15
# 18          14           F          15
# 19          20           F          18
# 20           F           8          11
# 21           2           F           7
# 22           7           F           9
# 23          13           F          15
# 24           9           F           9
# 25           7           F          10
# 26           F           7          12
# 27           2           F           7
# 28           4           F           6
# 29           5           F           8

# %%
data_2022_1.head(30)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN        NaN        NaN
# 1          NaN         NaN         NaN         NaN        NaN        NaN
# 2          NaN         NaN         NaN         NaN        NaN        NaN
# 3          NaN         NaN         NaN         NaN        NaN        NaN
# 4          NaN         NaN         NaN         NaN        NaN        NaN
# 5          NaN         NaN         NaN         NaN        NaN        NaN
# 6          NaN         NaN         NaN  Práctica C        NaN        NaN
# 7          NaN         NaN         NaN           1          2          3
# 8          NaN         NaN         NaN           1         10          7
# 9          NaN         NaN         NaN          12          7          6
# 10         NaN         NaN         NaN           F         10          9
# 11         NaN         NaN         NaN          12          7          F
# 12         NaN         NaN         NaN          19         16         18
# 13         NaN         NaN         NaN          11          8          8
# 14         NaN         NaN         NaN          11         14         10
# 15         NaN         NaN         NaN          12         15         13
# 16         NaN         NaN         NaN          13         14         10
# 17         NaN         NaN         NaN          10          5         11
# 18         NaN         NaN         NaN          10          5          F
# 19         NaN         NaN         NaN          13         12          F
# 20         NaN         NaN         NaN           3         13          F
# 21         NaN         NaN         NaN          15         16          9
# 22         NaN         NaN         NaN          16         11         15
# 23         NaN         NaN         NaN           7          8          F
# 24         NaN         NaN         NaN           9          9          F
# 25         NaN         NaN         NaN           F          4          7
# 26         NaN         NaN         NaN          11         10          5
# 27         NaN         NaN         NaN           7          7          4
# 28         NaN         NaN         NaN           9         12          1
# 29         NaN         NaN         NaN           7          2          F
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0         NaN         NaN        NaN        NaN         NaN         NaN
# 1         NaN         NaN        NaN        NaN         NaN         NaN
# 2         NaN         NaN        NaN        NaN         NaN         NaN
# 3         NaN         NaN        NaN        NaN         NaN         NaN
# 4         NaN         NaN        NaN        NaN         NaN         NaN
# 5         NaN         NaN        NaN        NaN         NaN         NaN
# 6         NaN  Práctica D        NaN        NaN         NaN      Examen
# 7           4           1          2          3           4           1
# 8           9          16         12         14          12           7
# 9          13          15         13          8          14           7
# 10         20          18         15         17          18          13
# 11          F          17         11         12           8           5
# 12         20          18         17         18          20          19
# 13         15          15         14         13          16           8
# 14         17          16         16         14          15          10
# 15         19          14         10         14          17          15
# 16         19          18         17         16          16          14
# 17         17          14         12         15          13           8
# 18         17          16          6         12          16           9
# 19         19          16          9          6          19          10
# 20          8          13         14          9           7           7
# 21         16          15         16         14          18          15
# 22         20          18         18         17          18          13
# 23          7          14         11         10           6           8
# 24          F          12         10          7           6           5
# 25          F          16          6          2           F           7
# 26         11          16         12         16          14          10
# 27          2          12          8          9          11           8
# 28         15          15         15         15          13          16
# 29          F          14         10          5           F           3
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN    Examen 3        Nota
# 7            2           1         NaN
# 8           12           F          10
# 9            7           F           9
# 10           4           F          11
# 11           F           F           5
# 12          18           F          19
# 13           2           F           8
# 14          13           F          13
# 15          10           F          14
# 16          10           F          14
# 17          13           F          12
# 18           3           F           8
# 19           9           F          12
# 20           N           F           6
# 21           9           F          14
# 22          10           F          14
# 23           9           F           9
# 24           F           F           4
# 25           F           F           4
# 26           6           F          10
# 27           4           F           7
# 28          11           F          13
# 29           F           F           3

# %%
print(data_2022_2.shape)
print(data_2022_1.shape)
# Out:
# (68, 15)
# (58, 15)

# %% [markdown]
# #**Limpieza de filas y columnas vacias**

# %%
def eliminar_vacios(data):
  #Elimina filas NaN
  data = data.dropna(how='all')

  #Elimina columnas NaN
  data = data.dropna(how='all', axis=1)

  #Limpieza de encabezados
  data = data.drop(data.index[:2])

  return data

# %%
#Eliminar vacios
data_2022_2_clean = eliminar_vacios(data_2022_2)
data_2022_1_clean = eliminar_vacios(data_2022_1)

# %%
#data_2022_2_clean.head()

# %%
#data_2022_2_clean.shape

# %%
#Nombrar las columnas

nombre_columnas = ['Practica C1','Practica C2','Practica C3','Practica C4','Practica D1','Practica D2','Practica D3','Practica D4','Examen 1','Examen 2','Examen 3','Promedio']
len(nombre_columnas)
# Out:
# 12

# %%
#Renombrar las cabeceras en la tabla
data_2022_2_clean.columns = nombre_columnas
data_2022_1_clean.columns = nombre_columnas

#data_2022_2_clean.columns

# %%
#Reseteando los indices
data_2022_2_clean.reset_index(drop=True, inplace=True) #inplace hace que se sobreescriba la variable
data_2022_1_clean.reset_index(drop=True, inplace=True) #inplace hace que se sobreescriba la variable

# %%
#data_2022_2_clean.head()

# %%
#Agregar una columna al inicio del dataset
id2 = list(range(1, data_2022_2_clean.shape[0]+1))
id1 = list(range(1, data_2022_1_clean.shape[0]+1))
#print(id)

data_2022_2_clean.insert(0, 'ID', id2)
data_2022_1_clean.insert(0, 'ID', id1)
#data_2022_2_clean.head()

# %%
#data_2022_2_clean.info()

# %%
#Revisar los valores de la columna (descubrir porque Dtype es 'object')
#data_2022_2_clean['Practica C1'].value_counts()

# %%
#Reemplazando los 'F' (faltas) de las practicas
#data_2022_2_clean['Practica C1'].replace('F',0)

# %%
#Ver los nombres de las columnas de practicas
#data_2022_2_clean.columns[1:9]

#Seccion de tabla con los valores de las practicas
#data_2022_2_clean[data_2022_2_clean.columns[1:9]]

# %%
columnas_practicas = ['Practica C1', 'Practica C2', 'Practica C3', 'Practica C4', 'Practica D1', 'Practica D2', 'Practica D3', 'Practica D4']

# %%
# Funcion para reemplazar strings por 0 en columnas de practicas
def replace_str(data, column):
  data[column] = data[column].applymap(lambda x: 0 if isinstance(x, str) else x)
  return data

#Aplicar la funcion en nuestros datasets
data_2022_2_rep = replace_str(data_2022_2_clean, columnas_practicas)
data_2022_1_rep = replace_str(data_2022_1_clean, columnas_practicas)

# %%
#ata_2022_2_clean.describe()

# %%
#data_2022_2_clean.head()

# %%
#Crear una columna que muestre el promedio de las practicas C, obviando el menor y agrega una columna con los resultados

practica_c = ['Practica C1','Practica C2','Practica C3','Practica C4']

def prom_pc(row):
    return (sum(row) - min(row)) / (len(row) - 1)
    print(row)

data_2022_2_rep['prom_pc'] = data_2022_2_rep[practica_c].apply(prom_pc, axis=1)
data_2022_1_rep['prom_pc'] = data_2022_1_rep[practica_c].apply(prom_pc, axis=1)
#print(data_2022_2['prom_pc'])

# %%
#Crear una columna que muestre el promedio de las practicas D, obviando el menor y agrega una columna con los resultados

practica_d = ['Practica D1','Practica D2','Practica D3','Practica D4']

def prom_pd(row):
    return (sum(row) - min(row)) / (len(row) - 1)

data_2022_2_rep['prom_pd'] = data_2022_2_rep[practica_d].apply(prom_pd, axis=1)
data_2022_1_rep['prom_pd'] = data_2022_1_rep[practica_d].apply(prom_pd, axis=1)
#print(data_2022_2['prom_pd'])

# %%
#Crear una columna que muestre el promedio de los examenes, reemplazando las faltas en alguno de los 2 primeros por el 3ro

examen = ['Examen 1','Examen 2','Examen 3']

# function to calculate the average marks
def calc_avg(row):
    exam1 = row['Examen 1']
    exam2 = row['Examen 2']
    exam3 = row['Examen 3']

    scores = []

    # Check Examen 1
    if str(exam1).isdigit():
        scores.append(exam1)
    else:
        scores.append(0)

    # Check Examen 2
    if str(exam2).isdigit():
        scores.append(exam2)
    else:
        if str(scores[0]).isdigit() and str(exam3).isdigit():
            scores.append(exam3)
        else:
            scores.append(0)

    return sum(scores) / 2

# Apply the custom function to each row
data_2022_2_rep['prom_ex'] = data_2022_2_rep.apply(calc_avg, axis=1)
data_2022_1_rep['prom_ex'] = data_2022_1_rep.apply(calc_avg, axis=1)

# display the dataFrame
#data_2022_2.head(50)

# %%
#data_2022_2_clean.head(50)

# %%
#Promedio Final

import math

def round_half_up(number):
    return int(math.floor(number + 0.5))

def prom_final(row):
  prom_pc = row['prom_pc']
  prom_pd = row['prom_pd']
  prom_ex = row['prom_ex']
  return round_half_up(prom_pc*0.25 + prom_pd*0.15 + prom_ex*0.6)

data_2022_2_rep['prom_final'] = data_2022_2_rep.apply(prom_final, axis=1)
data_2022_1_rep['prom_final'] = data_2022_1_rep.apply(prom_final, axis=1)

# %%
data_2022_2_rep.head(15)
# Out:
#     ID  Practica C1  Practica C2  Practica C3  Practica C4  Practica D1  \
# 0    1            6           12            8            6           10
# 1    2            0            0            0            0            5
# 2    3           11           17           14           12           13
# 3    4           16           20           17           20           20
# 4    5           17           14           11           10           16
# 5    6           10           13           10           12           13
# 6    7            7           14           11           13            5
# 7    8           18           19           10           12           19
# 8    9            9            8           11           14           13
# 9   10           18           18           17           11           14
# 10  11           17           18           10           15           18
# 11  12           20           16           10           13           17
# 12  13           10            9            4           13           16
# 13  14            4           12            6            6           14
# 14  15           15           10            8           14           15
#
#     Practica D2  Practica D3  Practica D4 Examen 1 Examen 2 Examen 3  \
# 0            12           15           13       13        F       11
# 1             0            0            0        F        F        F
# 2            17           18           17       16       15        F
# 3            19           19           18       20       19        F
# 4            15           15           15       10       12        F
# 5            10           17           12       10        9        F
# 6            12           15           11       12       10        F
# 7            19           18           13       16       13        F
# 8            11           16           17       13       13        F
# 9            13           19           18       16       12        F
# 10           18           18           19       14       14        F
# 11           13           18           19       16       20        F
# 12           12           15           11       13        F        8
# 13           12           10           10        7        2        F
# 14           10            9           16        4        7        F
#
#     Promedio    prom_pc    prom_pd  prom_ex  prom_final
# 0         11   8.666667  13.333333     12.0          11
# 1   Retirado   0.000000   1.666667      0.0           0
# 2         15  14.333333  17.333333     15.5          15
# 3         19  19.000000  19.333333     19.5          19
# 4         12  14.000000  15.333333     11.0          12
# 5         11  11.666667  14.000000      9.5          11
# 6         12  12.666667  12.666667     11.0          12
# 7         16  16.333333  18.666667     14.5          16
# 8         13  11.333333  15.333333     13.0          13
# 9         15  17.666667  17.000000     14.0          15
# 10        15  16.666667  18.333333     14.0          15
# 11        18  16.333333  18.000000     18.0          18
# 12        11  10.666667  14.333333     10.5          11
# 13         7   8.000000  12.000000      4.5           7
# 14         9  13.000000  13.666667      5.5           9

# %%
data_2022_1_rep.head(15)
# Out:
#     ID  Practica C1  Practica C2  Practica C3  Practica C4  Practica D1  \
# 0    1            1           10            7            9           16
# 1    2           12            7            6           13           15
# 2    3            0           10            9           20           18
# 3    4           12            7            0            0           17
# 4    5           19           16           18           20           18
# 5    6           11            8            8           15           15
# 6    7           11           14           10           17           16
# 7    8           12           15           13           19           14
# 8    9           13           14           10           19           18
# 9   10           10            5           11           17           14
# 10  11           10            5            0           17           16
# 11  12           13           12            0           19           16
# 12  13            3           13            0            8           13
# 13  14           15           16            9           16           15
# 14  15           16           11           15           20           18
#
#     Practica D2  Practica D3  Practica D4 Examen 1 Examen 2 Examen 3 Promedio  \
# 0            12           14           12        7       12        F       10
# 1            13            8           14        7        7        F        9
# 2            15           17           18       13        4        F       11
# 3            11           12            8        5        F        F        5
# 4            17           18           20       19       18        F       19
# 5            14           13           16        8        2        F        8
# 6            16           14           15       10       13        F       13
# 7            10           14           17       15       10        F       14
# 8            17           16           16       14       10        F       14
# 9            12           15           13        8       13        F       12
# 10            6           12           16        9        3        F        8
# 11            9            6           19       10        9        F       12
# 12           14            9            7        7        N        F        6
# 13           16           14           18       15        9        F       14
# 14           18           17           18       13       10        F       14
#
#       prom_pc    prom_pd  prom_ex  prom_final
# 0    8.666667  14.000000      9.5          10
# 1   10.666667  14.000000      7.0           9
# 2   13.000000  17.666667      8.5          11
# 3    6.333333  13.333333      2.5           5
# 4   19.000000  18.666667     18.5          19
# 5   11.333333  15.000000      5.0           8
# 6   14.000000  15.666667     11.5          13
# 7   15.666667  15.000000     12.5          14
# 8   15.333333  17.000000     12.0          14
# 9   12.666667  14.000000     10.5          12
# 10  10.666667  14.666667      6.0           8
# 11  14.666667  14.666667      9.5          12
# 12   8.000000  12.000000      3.5           6
# 13  15.666667  16.333333     12.0          14
# 14  17.000000  18.000000     11.5          14

# %% [markdown]
# #**Comparacion de datos**

# %%
data_2022_1_rep.describe().T
# Out:
#              count       mean        std  min        25%        50%  \
# ID            50.0  25.500000  14.577380  1.0  13.250000  25.500000
# Practica C1   50.0   9.360000   5.412608  0.0   6.250000   9.500000
# Practica C2   50.0  11.360000   4.579279  0.0   8.000000  11.000000
# Practica C3   50.0   6.980000   5.246923  0.0   0.250000   8.500000
# Practica C4   50.0  13.480000   6.996326  0.0  10.000000  16.000000
# Practica D1   50.0  15.140000   2.240718  9.0  14.000000  15.000000
# Practica D2   50.0  12.280000   3.686932  0.0  11.000000  12.500000
# Practica D3   50.0  12.000000   4.463000  0.0   9.000000  13.500000
# Practica D4   50.0  13.080000   5.290886  0.0  11.250000  15.000000
# prom_pc       50.0  12.006667   4.538318  0.0   9.916667  12.666667
# prom_pd       50.0  14.006667   3.211014  3.0  13.083333  14.666667
# prom_ex       50.0   9.270000   4.456376  0.0   6.250000   9.500000
# prom_final    50.0  10.720000   4.150436  0.0   8.000000  11.000000
#
#                    75%        max
# ID           37.750000  50.000000
# Practica C1  13.000000  19.000000
# Practica C2  15.000000  20.000000
# Practica C3  10.750000  18.000000
# Practica C4  19.000000  20.000000
# Practica D1  17.000000  19.000000
# Practica D2  15.000000  18.000000
# Practica D3  15.000000  18.000000
# Practica D4  16.750000  20.000000
# prom_pc      15.583333  19.000000
# prom_pd      15.666667  18.666667
# prom_ex      12.000000  19.500000
# prom_final   13.750000  19.000000

# %%
promedios_comparacion = ['prom_pc','prom_pd','prom_ex','prom_final']

# %%
data_2022_1_est = data_2022_1_rep[promedios_comparacion].describe().T

# %%
data_2022_2_est = data_2022_2_rep[promedios_comparacion].describe().T

# %%
data_2022_1_est.insert(0, 'ID', range(1,len(data_2022_1_est)+1))
data_2022_2_est.insert(0, 'ID', range(1,len(data_2022_2_est)+1))

# %%
tabla_comparada = pd.merge(data_2022_1_est, data_2022_2_est, on='ID')

# %%
tabla_comparada.head()
# Out:
#    ID  count_x     mean_x     std_x  min_x      25%_x      50%_x      75%_x  \
# 0   1     50.0  12.006667  4.538318    0.0   9.916667  12.666667  15.583333
# 1   2     50.0  14.006667  3.211014    3.0  13.083333  14.666667  15.666667
# 2   3     50.0   9.270000  4.456376    0.0   6.250000   9.500000  12.000000
# 3   4     50.0  10.720000  4.150436    0.0   8.000000  11.000000  13.750000
#
#        max_x  count_y     mean_y     std_y  min_y      25%_y      50%_y  \
# 0  19.000000     60.0   9.633333  5.152185    0.0   4.916667   9.833333
# 1  18.666667     60.0  12.661111  3.942378    0.0  10.666667  13.166667
# 2  19.500000     60.0   8.050000  5.432716    0.0   3.375000   8.500000
# 3  19.000000     60.0   9.183333  4.935144    0.0   5.000000   9.500000
#
#        75%_y      max_y
# 0  13.083333  19.000000
# 1  15.083333  19.333333
# 2  12.000000  19.500000
# 3  12.000000  19.000000

# %%
# Agregar columnas calculando la variacion de los promedios
# Graficar (usando 'for')
# Analisis de las faltas

# %%
import seaborn as sns

# %%
sns.histplot(data=data_2022_1_rep, x=data_2022_1_rep['Practica C1'])
# Out:
# <Axes: xlabel='Practica C1', ylabel='Count'>
